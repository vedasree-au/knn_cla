# %% [markdown]
# why do we need knn?
#
# -it is used for classification problem
#
# -recomendation system
#
# -pattern recognization
#
# -similarity based predictions
#
#     Ex: Movie recommendation
#
#     Customer segmentation
#
#     Handwriting recognition
#
#     Disease prediction
#
# What is KNN?
#
# KNN works using similarity and distance. It doesn't learn equations like logistic and linear regression.
#
# How KNN works?
#
# Step 1: Choose the K value
#
# Step 2: Find the nearest 3 neighbours
#
# Step 3: Check majority class
#
# Step 4: Assign predicted class
#
# Distance metrics:
#
# KNN depends upon metrics. We use Eucledeon distance
#
# Distance = sqrt (x2-x1)^2 + (y2-y1)^2

# %%
import math
x1=2
y1=3
x2=6
y2=7
distance=math.sqrt((x2-x1)**2 + (y2-y1)**2)
print("Distance:",distance)
# Out:
# Distance: 5.656854249492381

# %% [markdown]
# 1. Eucledeon = continuous numerical data
#
# 2. Manhattan = Grid based distance
#
# 3. Minkowski = Generalized distance
#
# 4. Hamming = Binary categorical data

# %% [markdown]
# ## knn classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
# load
iris=load_iris()
x=iris.data
y=iris.target
# split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=42)

 # model
knn_classifier=KNeighborsClassifier(
  n_neighbors=5,
  metric='minkowski',
  p=2
 )


knn_classifier.fit(x_train,y_train)
y_pred=knn_classifier.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:",accuracy)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 22
#      20 knn_classifier.fit(x_train,y_train)
#      21 y_pred=knn_classifier.predict(x_test)
# ---> 22 accuracy=accuracy_score(y_test.y_pred)
#      23 print("Accuracy:",accuracy)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'y_pred'

# %%
x=iris.data
y=iris.target
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
# model
knn=KNeighborsClassifier(
  n_neighbors=5,
  metric='minkowski',
  p=2
 )
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
print("Classification Report:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy: 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 14
#      12 accuracy=accuracy_score(y_test,y_pred)
#      13 print("Accuracy:",accuracy)
# ---> 14 print("Classification Report:\n",classification_report(y_test,y_pred))
#      15 print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
#
# NameError: name 'classification_report' is not defined
